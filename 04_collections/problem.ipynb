# %% [markdown]
# Q.no.1 Given a list:
#
# nums = [1,2,2,3,4,4,5]
#
# Remove duplicates without using set() directly.
#
# (You may use a loop.)

# %% [markdown]
# 2️⃣ Count Frequency (Manual)
#
# Given:
#
# s = "banana"
#
# Return a dictionary of character frequencies.
#
# Expected:
#
# {'b':1, 'a':3, 'n':2}
#
# No Counter. Manual logic.

# %% [markdown]
# 3️⃣ Dictionary Key Update Logic
#
# What is the output?
#
# d = {} d["a"] = 1 d["b"] = 2 d["a"] += 3 print(d)
#
# Explain why.

# %% [markdown]
# 4️⃣ Set Behavior Check
#
# What is the output?
#
# s = {1,2,3} s.add(2) print(s)
#
# Why?

# %% [markdown]
# 5️⃣ First Non-Repeating Character
#
# Given:
#
# s = "swiss"
#
# Return the first character that appears only once.
#
# Expected:
#
# 'w'
#
# Think:
#
# First build frequency
#
# Then scan again

# %% [markdown]
# 6️⃣ Check Two Lists Have Same Elements (Order Doesn't Matter) a = [1,2,2,3] b = [2,1,3,2]
#
# Return True if they contain the same elements with same counts.
#
# No sorting allowed.

# %% [markdown]
# 7️⃣ Detect Duplicate
#
# Given a list, return True if any number appears more than once.
#
# Do it in O(n).

# %% [markdown]
# 🔥 LEVEL 3 — Tuple + Hashability Thinking
# 8️⃣ Group Words by Length
# words = ["cat","bat","apple","dog","egg"]
#
# Return:
#
# {
#   3: ["cat","bat","dog","egg"],
#   5: ["apple"]
# }
#
# Use dictionary.

# %% [markdown]
# 9️⃣ Convert List of Tuples to Dict
# pairs = [("a",1),("b",2),("a",3)]
#
# What should the final dictionary be?
# Explain overwrite behavior.

# %% [markdown]
# 🔟 Find Intersection of Two Lists (No built-in set intersection)
# a = [1,2,3,4]
# b = [3,4,5,6]
#
# Return:
#
# [3,4]
#
# Must use set or dictionary logic.
