# %%
x = 10
print("x is :",x,"id:",id(x))

y = 20
print("y is :",y,"id:",id(y))

a = [1,2]
b = [1,2]
print("a == b",a==b)
print("a is b",a is b)
print("id(a) :",id(a))
print("id(b) :",id(b))
# Out:
# x is : 10 id: 4312147448
# y is : 20 id: 4312147768
# a == b True
# a is b False
# id(a) : 4403206592
# id(b) : 4403205952

# %%
x = 1000
y = 1000
print(id(x), id(y))
# Out:
# 4401034832 4401034928

# %%
a = [1,2]
b = a
a.append(3)
print("a is b :", a is b)
print("id of a :",id(a))
print("id of b :",id(b))
# Out:
# a is b : True
# id of a : 4403203968
# id of b : 4403203968

# %%
x = 5
y = x
x += 1
print(y)
print(x)
# Out:
# 5
# 6

# %%
a=(1,
